# %%
import pandas as pd
import numpy as np


import pandas as pd
import re
import numpy as np

from functools import reduce
import nltk
import stop_words
import gensim
import math
import random
import re

# %%
train_set = pd.read_csv('train.csv')
test_set = pd.read_csv('test.csv')

# %%
train_set.head(1)
# Out:
#                  id                                       comment_text  toxic  \
# 0  0000997932d777bf  Explanation\nWhy the edits made under my usern...      0
#
#    severe_toxic  obscene  threat  insult  identity_hate
# 0             0        0       0       0              0

# %%
test_set.head(1)
# Out:
#                  id                                       comment_text
# 0  00001cee341fdb12  Yo bitch Ja Rule is more succesful then you'll...

# %%
train_set[train_set['toxic'] == 1]
# Out:
#                       id                                       comment_text  \
# 6       0002bcb3da6cb337       COCKSUCKER BEFORE YOU PISS AROUND ON MY WORK
# 12      0005c987bdfc9d4b  Hey... what is it..\n@ | talk .\nWhat is it......
# 16      0007e25b2121310b  Bye! \n\nDon't look, come or think of comming ...
# 42      001810bf8c45bf5f  You are gay or antisemmitian? \n\nArchangel WH...
# 43      00190820581d90ce           FUCK YOUR FILTHY MOTHER IN THE ASS, DRY!
# 44      001956c382006abd  I'm Sorry \n\nI'm sorry I screwed around with ...
# 51      001dc38a83d420cf  GET FUCKED UP. GET FUCKEEED UP.  GOT A DRINK T...
# 55      0020e7119b96eeeb  Stupid peace of shit stop deleting my stuff as...
# 56      0020fd96ed3b8c8b  =Tony Sidaway is obviously a fistfuckee. He lo...
# 58      0021fe88bc4da3e6  My Band Page's deletion. You thought I was gon...
# 59      002264ea4d5f2887  Why can't you believe how fat Artie is? Did yo...
# ...

# %%
import text_processing

# %%
import imp

# %%
text_processing = imp.reload(text_processing)

# %% [markdown]
# ## training for toxic binary detection

# %%
lines = []
labels = []

for i in range(len(train_set)):
    txt = train_set.iloc[i]['comment_text']
    toxic_label = train_set.iloc[i]['toxic']
    lines.append(txt)
    labels.append(toxic_label)

# %%
vecs = np.array(text_processing.lines2vec(lines,6))
# Out:
# /home/lyan/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:1110: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/lyan/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/lyan/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:1110: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/lyan/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/lyan/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:1110: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/lyan/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:1110: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# ...

# %%
pd.DataFrame(np.array(vecs)).to_csv('glove6_50d.csv')

# %%
vecs = pd.read_csv('glove840300d.csv')

# %% [markdown]
# ## training model

# %%
X = np.zeros((vecs.shape[0],50))
Y = np.array(labels)

# %%
for i in range(vecs.shape[0]):
    X[i] = vecs[i]

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split

# %%
trainX, testX, trainY, testY = train_test_split(X, Y)

# %%
dtrain = xgb.DMatrix(trainX, trainY)
dtest = xgb.DMatrix(testX, testY)

# %%
param = {'silent':1, 'objective':'binary:logistic' }
param['nthread'] = 6
param['eval_metric'] = 'error'
param['eta'] = 0.075
param['max_depth'] = 5
param['silent'] = 1
param['n_estimators'] = 500
param['early_stopping_rounds'] = 30

watchlist = [ (dtrain,'train'), (dtest, 'test') ]

# %%
bst = xgb.train(param, dtrain, 1000, watchlist,verbose_eval=100)
# Out:
# [0]	train-error:0.082471	test-error:0.0841
# [100]	train-error:0.063136	test-error:0.068709
# [200]	train-error:0.05666	test-error:0.066302
# [300]	train-error:0.052466	test-error:0.06545
# [400]	train-error:0.049433	test-error:0.065024
# [500]	train-error:0.046391	test-error:0.064548
# [600]	train-error:0.043274	test-error:0.064447
# [700]	train-error:0.040517	test-error:0.064297
# [800]	train-error:0.03796	test-error:0.064071
# [900]	train-error:0.035353	test-error:0.063595
# [999]	train-error:0.033047	test-error:0.06372

# %% [markdown]
# ## doing predict

# %%
test_lines = []

for i in range(len(test_set)):
    txt = test_set.iloc[i]['comment_text']
    test_lines.append(txt)

# %%
vecs = np.array(text_processing.lines2vec(test_lines,6))
# Out:
# /home/lyan/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:1110: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/lyan/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/lyan/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:1110: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/lyan/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:1110: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/lyan/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:1110: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/lyan/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ...

# %%
X = np.zeros((vecs.shape[0],50))
for i in range(vecs.shape[0]):
    X[i] = vecs[i]

# %%
pred = bst.predict(xgb.DMatrix(X))
